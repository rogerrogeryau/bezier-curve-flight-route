# %%
import pandas as pd
import numpy as np

# %%
import codecs
import json
with open('./hutcho_airport.json', 'r',encoding="utf8") as f:
    hutcho_airport = json.load(f)

# %%
# hutcho_airport

# %%
# type(hutcho_airport)
# Out:
# dict

# %%
hutcho_airport_v2 = {}

for i in hutcho_airport:
#     print(hutcho_airport[i]['iata'])

#     hutcho_airport[i]
#     hutcho_airport[i]['iata']
#     print(hutcho_airport[i])
#     hutcho_airport_v2[hutcho_airport[i]['iata']] = ''
#     print(hutcho_airport[i]['iata'])
#     hutcho_airport_v2[i] = ""
#     print(hutcho_airport[i]['iata'])
    key_name = hutcho_airport[i]['iata']
    hutcho_airport_v2[key_name] = hutcho_airport[i]

# %%
hutcho_airport_v2
# Out:
# {'HIR': {'icao': 'AGGH',
#   'iata': 'HIR',
#   'name': 'Honiara International Airport',
#   'city': 'Honiara',
#   'state': 'Guadalcanal',
#   'country': 'SB',
#   'elevation': 28,
#   'lat': -9.4280004501,
#   'lon': 160.0549926758,
#   'tz': 'Pacific/Guadalcanal'},
#  'INU': {'icao': 'ANYN',
#   'iata': 'INU',
#   'name': 'Nauru International Airport',
#   'city': 'Yaren District',
#   'state': 'Yaren',
#   'country': 'NR',
#   'elevation': 22,
#   'lat': -0.547458,
#   'lon': 166.919006,
#   'tz': 'Pacific/Nauru'},
#  'GKA': {'icao': 'AYGA',
#   'iata': 'GKA',
#   'name': 'Goroka Airport',
#   'city': 'Goronka',
#   'state': 'Eastern Highlands',
#   'country': 'PG',
#   'elevation': 5282,
#   'lat': -6.0816898346,
#   'lon': 145.391998291,
#   'tz': 'Pacific/Port_Moresby'},
#  'HKN': {'icao': 'AYHK',
#   'iata': 'HKN',
#   'name': 'Kimbe Airport',
#   'city': 'Hoskins',
#   'state': 'West New Britain',
#   'country': 'PG',
#   'elevation': 66,
#   'lat': -5.4621701241,
# ...

# %%
with open('./hutcho_airport_v2.json', 'w') as fp:
    json.dump(hutcho_airport_v2, fp)
